# %% [markdown]
# Here's an example Sankey diagram from Plotly:

# %%
# %pip install --quiet -e ../../doodl/ scipy
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show doodl
# Out:
# Name: doodl
# Version: 0.7.8
# Summary: A python module for including beautiful charts in Markdown for conversion to HTML
# Home-page:
# Author:
# Author-email: "doodl.ai" <info@doodl.ai>
# License:
# Location: /home/scott/Projects/.Linux-virenv/hubbl/lib/python3.12/site-packages
# Editable project location: /home/scott/Projects/hubbl/doodl/doodl
# Requires: beautifulsoup4, colorcet, ipython, playwright, pypandoc, requests, seaborn
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import doodl

doodl.piechart(
    data=[
  { "label": "Apples", "value": 10 },
  { "label": "Bananas", "value": 20 },
  { "label": "Cherries", "value": 15 },
  { "label": "Grapes", "value": 25 }
],
    width=450,
    height=450,
    colors='deep'
)
# Out:
# Rendering chart piechart with fields {'continuous_rotation': False, 'donut': False} and kwargs {'colors': 'deep',
#  'data': [{'label': 'Apples', 'value': 10},
#           {'label': 'Bananas', 'value': 20},
#           {'label': 'Cherries', 'value': 15},
#           {'label': 'Grapes', 'value': 25}],
#  'height': 450,
#  'width': 450}
# <p><span class="chart-container" id="piechart_0"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.piechart("#piechart_0",
#                 [],
#                 {"width": 450, "height": 450},
#                 {},
#                 ["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B3", "#937860", "#DA8BC3", "#8C8C8C", "#CCB974", "#64B5CD"],
#                 false,
#                 false
#             );
# </script>
# <p><span class="chart-container" id="piechart_0"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.piechart("#piechart_0",
#                 [],
#                 {"width": 450, "height": 450},
#                 {},
#                 ["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B3", "#937860", "#DA8BC3", "#8C8C8C", "#CCB974", "#64B5CD"],
#                 false,
#                 false
#             );
# </script>

# %%
import doodl

doodl.piechart(
    file={"path":"../pie.json","format":"json"},
    size={"width":450,"height":450},
    colors='deep'
)
# Out:
# Rendering chart piechart with fields {'donut': False, 'continuous_rotation': False} and kwargs {'file': {'path': '../pie.json', 'format': 'json'}, 'size': {'width': 450, 'height': 450}, 'colors': 'deep'}
# <p><span class="chart-container" id="piechart_1"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.piechart(#piechart_1,
#                 [],
#                 {},
#                 {},
#                 ['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD'],
#                 False,
#                 False
#             );
# </script>
# <p><span class="chart-container" id="piechart_1"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.piechart(#piechart_1,
#                 [],
#                 {},
#                 {},
#                 ['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD'],
#                 False,
#                 False
#             );
# </script>

# %%
import doodl

doodl.linechart(
    path="../data/xy.csv",
    width=450,
    height=450,
    colors='deep'
)
# Out:
# Rendering chart linechart with fields {'curved': False} and kwargs {'path': '../data/xy.csv', 'width': 450, 'height': 450, 'colors': 'deep'}
# <p><span class="chart-container" id="linechart_2"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.linechart(#linechart_2,
#                 [{'x': '11', 'y': '101'}, {'x': '21', 'y': '201'}, {'x': '31', 'y': '151'}, {'x': '41', 'y': '251'}, {'x': '51', 'y': '301'}, {'x': '61', 'y': '351'}],
#                 {'width': 450, 'height': 450},
#                 {},
#                 ['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD'],
#                 False
#             );
# </script>
# <p><span class="chart-container" id="linechart_2"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.linechart(#linechart_2,
#                 [{'x': '11', 'y': '101'}, {'x': '21', 'y': '201'}, {'x': '31', 'y': '151'}, {'x': '41', 'y': '251'}, {'x': '51', 'y': '301'}, {'x': '61', 'y': '351'}],
#                 {'width': 450, 'height': 450},
#                 {},
#                 ['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD'],
#                 False
#             );
# </script>

# %%
import doodl

doodl.skey(
    file={"path":"../std_focus.json","format":"json"},
    colors='pastel',
    size={"width":1000,"height":500}
)
# Out:
# Rendering chart skey with fields {'link_color': 'source-target', 'node_align': 'left'} and kwargs {'file': {'path': '../std_focus.json', 'format': 'json'}, 'colors': 'pastel', 'size': {'width': 1000, 'height': 500}}
# <p><span class="chart-container" id="skey_5"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.skey("#skey_5",
#                 "[]",
#                 {"width": 1000, "height": 500},
#                 {"path": "../std_focus.json", "format": "json"},
#                 "['#A1C9F4', '#FFB482', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#DEBB9B', '#FAB0E4', '#CFCFCF', '#FFFEA3', '#B9F2F0']",
#                 "\"source-target\"",
#                 "\"left\""
#             );
# </script>
# <p><span class="chart-container" id="skey_5"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.skey("#skey_5",
#                 "[]",
#                 {"width": 1000, "height": 500},
#                 {"path": "../std_focus.json", "format": "json"},
#                 "['#A1C9F4', '#FFB482', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#DEBB9B', '#FAB0E4', '#CFCFCF', '#FFFEA3', '#B9F2F0']",
#                 "\"source-target\"",
#                 "\"left\""
#             );
# </script>

# %%
import pandas as pd
from scipy.stats import truncnorm
import seaborn as sns

n_companies = 500

data = {
    'margin': truncnorm.rvs(-3, 3, scale=0.05, size=n_companies),
    'growth': truncnorm.rvs(-3, 3, scale=1.0/3.0, size=n_companies),
    'volatility': truncnorm.rvs(-3, 3, loc=0.5, scale=0.5/3.0, size=n_companies),
}

df = pd.DataFrame(data)

df['accept'] = (df.margin / 0.15 + df.growth + (1.0 - df.volatility)) > 1

sns.pairplot(df, hue='accept')

# %%
import doodl

doodl.tree(
    data={
    "name": "root",
    "children": [
            { "name": "A", "value": 10 },
            { "name": "B", "value": 20 },
            { "name": "C", "children": [
                { "name": "C1", "value": 10 },
                { "name": "C2", "value": 5 },
                { "name": "C3", "value": 15 }
            ]},
            { "name": "D", "value": 40 }
        ]
    },
    size={"width":1000,"height":500},
    colors='deep',
    vertical=True
    )
# Out:
# Rendering chart tree with fields {'vertical': False} and kwargs {'data': {'name': 'root', 'children': [{'name': 'A', 'value': 10}, {'name': 'B', 'value': 20}, {'name': 'C', 'children': [{'name': 'C1', 'value': 10}, {'name': 'C2', 'value': 5}, {'name': 'C3', 'value': 15}]}, {'name': 'D', 'value': 40}]}, 'size': {'width': 1000, 'height': 500}, 'colors': 'deep', 'vertical': True}
# <p><span class="chart-container" id="tree_6"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.tree("#tree_6",
#                 {"name": "root", "children": [{"name": "A", "value": 10}, {"name": "B", "value": 20}, {"name": "C", "children": [{"name": "C1", "value": 10}, {"name": "C2", "value": 5}, {"name": "C3", "value": 15}]}, {"name": "D", "value": 40}]},
#                 {"width": 1000, "height": 500},
#                 "{}",
#                 "['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD']",
#                 true
#             );
# </script>
# <p><span class="chart-container" id="tree_6"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.tree("#tree_6",
#                 {"name": "root", "children": [{"name": "A", "value": 10}, {"name": "B", "value": 20}, {"name": "C", "children": [{"name": "C1", "value": 10}, {"name": "C2", "value": 5}, {"name": "C3", "value": 15}]}, {"name": "D", "value": 40}]},
#                 {"width": 1000, "height": 500},
#                 "{}",
#                 "['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD']",
#                 true
#             );
# </script>

# %%
import doodl

doodl.gantt(
  data=[
    { "task": "Planning", "start": "2024-03-01", "end": "2024-03-05" },
    { "task": "Design", "start": "2024-03-06", "end": "2024-03-12" },
    { "task": "Development", "start": "2024-03-13", "end": "2024-03-25" },
    { "task": "Testing", "start": "2024-03-26", "end": "2024-03-30" },
    { "task": "Deployment", "start": "2024-03-31", "end": "2024-04-02" }
  ],
  size={"width":1000,"height":500},
  colors='deep'
)
# Out:
# Rendering chart gantt with fields None and kwargs {'data': [{'task': 'Planning', 'start': '2024-03-01', 'end': '2024-03-05'}, {'task': 'Design', 'start': '2024-03-06', 'end': '2024-03-12'}, {'task': 'Development', 'start': '2024-03-13', 'end': '2024-03-25'}, {'task': 'Testing', 'start': '2024-03-26', 'end': '2024-03-30'}, {'task': 'Deployment', 'start': '2024-03-31', 'end': '2024-04-02'}], 'size': {'width': 1000, 'height': 500}, 'colors': 'deep'}
# <p><span class="chart-container" id="gantt_7"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.gantt("#gantt_7",
#                 [{"task": "Planning", "start": "2024-03-01", "end": "2024-03-05"}, {"task": "Design", "start": "2024-03-06", "end": "2024-03-12"}, {"task": "Development", "start": "2024-03-13", "end": "2024-03-25"}, {"task": "Testing", "start": "2024-03-26", "end": "2024-03-30"}, {"task": "Deployment", "start": "2024-03-31", "end": "2024-04-02"}],
#                 {"width": 1000, "height": 500},
#                 "{}",
#                 "['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD']"
#             );
# </script>
# <p><span class="chart-container" id="gantt_7"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.gantt("#gantt_7",
#                 [{"task": "Planning", "start": "2024-03-01", "end": "2024-03-05"}, {"task": "Design", "start": "2024-03-06", "end": "2024-03-12"}, {"task": "Development", "start": "2024-03-13", "end": "2024-03-25"}, {"task": "Testing", "start": "2024-03-26", "end": "2024-03-30"}, {"task": "Deployment", "start": "2024-03-31", "end": "2024-04-02"}],
#                 {"width": 1000, "height": 500},
#                 "{}",
#                 "['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD']"
#             );
# </script>

# %%
import doodl

doodl.chord(
data=[
  [0, 5, 10, 2],
  [5, 0, 3, 7],
  [10, 3, 0, 6],
  [2, 7, 6, 0]
],
  size={"width":500,"height":500},
  colors='deep'
)
# Out:
# Rendering chart chord with fields None and kwargs {'data': [[0, 5, 10, 2], [5, 0, 3, 7], [10, 3, 0, 6], [2, 7, 6, 0]], 'size': {'width': 500, 'height': 500}, 'colors': 'deep'}
# <p><span class="chart-container" id="chord_8"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.chord("#chord_8",
#                 [[0, 5, 10, 2], [5, 0, 3, 7], [10, 3, 0, 6], [2, 7, 6, 0]],
#                 {"width": 500, "height": 500},
#                 "{}",
#                 "['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD']"
#             );
# </script>
# <p><span class="chart-container" id="chord_8"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.chord("#chord_8",
#                 [[0, 5, 10, 2], [5, 0, 3, 7], [10, 3, 0, 6], [2, 7, 6, 0]],
#                 {"width": 500, "height": 500},
#                 "{}",
#                 "['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD']"
#             );
# </script>

# %%
import doodl

doodl.barchart(
data=[
  { "label": "Apples", "value": 10 },
  { "label": "Bananas", "value": 20 },
  { "label": "Cherries", "value": 15 },
  { "label": "Grapes", "value": 25 }
],
  size={"width":500,"height":500},
  colors=["#FF6700","#008000"],
  horizontal=True
)
# Out:
# Rendering chart barchart with fields {'horizontal': False} and kwargs {'data': [{'label': 'Apples', 'value': 10}, {'label': 'Bananas', 'value': 20}, {'label': 'Cherries', 'value': 15}, {'label': 'Grapes', 'value': 25}], 'size': {'width': 500, 'height': 500}, 'colors': ['#FF6700', '#008000'], 'horizontal': True}
# <p><span class="chart-container" id="barchart_9"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.barchart("#barchart_9",
#                 [{"label": "Apples", "value": 10}, {"label": "Bananas", "value": 20}, {"label": "Cherries", "value": 15}, {"label": "Grapes", "value": 25}],
#                 {"width": 500, "height": 500},
#                 "{}",
#                 "['#FF6700', '#008000', '#FF6700', '#008000', '#FF6700', '#008000', '#FF6700', '#008000', '#FF6700', '#008000']",
#                 true
#             );
# </script>
# <p><span class="chart-container" id="barchart_9"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.barchart("#barchart_9",
#                 [{"label": "Apples", "value": 10}, {"label": "Bananas", "value": 20}, {"label": "Cherries", "value": 15}, {"label": "Grapes", "value": 25}],
#                 {"width": 500, "height": 500},
#                 "{}",
#                 "['#FF6700', '#008000', '#FF6700', '#008000', '#FF6700', '#008000', '#FF6700', '#008000', '#FF6700', '#008000']",
#                 true
#             );
# </script>

# %%
import doodl

doodl.barchart(
data=[
  { "label": "Apples", "value": 100000000 },
  { "label": "Bananas", "value": 200000000 },
  { "label": "Cherries", "value": 150000000 },
  { "label": "Grapes", "value": 250000000 }
],
  size={"width":500,"height":500},
  colors=["#FF6700","#008000"],
  horizontal=False
)
# Out:
# Rendering chart barchart with fields {'horizontal': False} and kwargs {'data': [{'label': 'Apples', 'value': 100000000}, {'label': 'Bananas', 'value': 200000000}, {'label': 'Cherries', 'value': 150000000}, {'label': 'Grapes', 'value': 250000000}], 'size': {'width': 500, 'height': 500}, 'colors': ['#FF6700', '#008000'], 'horizontal': False}
# <p><span class="chart-container" id="barchart_10"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.barchart("#barchart_10",
#                 [{"label": "Apples", "value": 100000000}, {"label": "Bananas", "value": 200000000}, {"label": "Cherries", "value": 150000000}, {"label": "Grapes", "value": 250000000}],
#                 {"width": 500, "height": 500},
#                 "{}",
#                 "['#FF6700', '#008000', '#FF6700', '#008000', '#FF6700', '#008000', '#FF6700', '#008000', '#FF6700', '#008000']",
#                 false
#             );
# </script>
# <p><span class="chart-container" id="barchart_10"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.barchart("#barchart_10",
#                 [{"label": "Apples", "value": 100000000}, {"label": "Bananas", "value": 200000000}, {"label": "Cherries", "value": 150000000}, {"label": "Grapes", "value": 250000000}],
#                 {"width": 500, "height": 500},
#                 "{}",
#                 "['#FF6700', '#008000', '#FF6700', '#008000', '#FF6700', '#008000', '#FF6700', '#008000', '#FF6700', '#008000']",
#                 false
#             );
# </script>

# %%
import doodl

doodl.voronoi(
data=[
  { "x": 100, "y": 200, "name": "A" },
  { "x": 150, "y": 80, "name": "B" },
  { "x": 300, "y": 150, "name": "C" },
  { "x": 400, "y": 300, "name": "D" },
  { "x": 250, "y": 400, "name": "E" },
  { "x": 500, "y": 200, "name": "F" },
  { "x": 350, "y": 100, "name": "G" },
  { "x": 180, "y": 320, "name": "H" },
  { "x": 90, "y": 450, "name": "I" },
  { "x": 600, "y": 350, "name": "J" }
],
  size={"width":850,"height":500},
  colors='flare'
)


import doodl

doodl.areachart(
data=[
  { "date": "2024-01-01", "catA": 10, "catB": 20, "catC": 30 },
  { "date": "2024-01-02", "catA": 15, "catB": 25, "catC": 35 },
  { "date": "2024-01-03", "catA": 20, "catB": 22, "catC": 28 },
  { "date": "2024-01-04", "catA": 18, "catB": 30, "catC": 25 },
  { "date": "2024-01-05", "catA": 22, "catB": 28, "catC": 32 },
  { "date": "2024-01-06", "catA": 19, "catB": 26, "catC": 29 },
  { "date": "2024-01-07", "catA": 24, "catB": 30, "catC": 35 },
  { "date": "2024-01-08", "catA": 28, "catB": 33, "catC": 40 }
],
  size={"width":500,"height":500},
  colors='flare',
)
# Out:
# Rendering chart voronoi with fields None and kwargs {'data': [{'x': 100, 'y': 200, 'name': 'A'}, {'x': 150, 'y': 80, 'name': 'B'}, {'x': 300, 'y': 150, 'name': 'C'}, {'x': 400, 'y': 300, 'name': 'D'}, {'x': 250, 'y': 400, 'name': 'E'}, {'x': 500, 'y': 200, 'name': 'F'}, {'x': 350, 'y': 100, 'name': 'G'}, {'x': 180, 'y': 320, 'name': 'H'}, {'x': 90, 'y': 450, 'name': 'I'}, {'x': 600, 'y': 350, 'name': 'J'}], 'size': {'width': 850, 'height': 500}, 'colors': 'flare'}
# <p><span class="chart-container" id="voronoi_11"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.voronoi("#voronoi_11",
#                 [{"x": 100, "y": 200, "name": "A"}, {"x": 150, "y": 80, "name": "B"}, {"x": 300, "y": 150, "name": "C"}, {"x": 400, "y": 300, "name": "D"}, {"x": 250, "y": 400, "name": "E"}, {"x": 500, "y": 200, "name": "F"}, {"x": 350, "y": 100, "name": "G"}, {"x": 180, "y": 320, "name": "H"}, {"x": 90, "y": 450, "name": "I"}, {"x": 600, "y": 350, "name": "J"}],
#                 {"width": 850, "height": 500},
#                 "{}",
#                 "['#EA9972', '#E88265', '#E36C5D', '#DA555C', '#CB4563', '#B73D6A', '#A1376F', '#8B3170', '#752C6E', '#5F2868']"
#             );
# </script>
# <p><span class="chart-container" id="voronoi_11"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.voronoi("#voronoi_11",
#                 [{"x": 100, "y": 200, "name": "A"}, {"x": 150, "y": 80, "name": "B"}, {"x": 300, "y": 150, "name": "C"}, {"x": 400, "y": 300, "name": "D"}, {"x": 250, "y": 400, "name": "E"}, {"x": 500, "y": 200, "name": "F"}, {"x": 350, "y": 100, "name": "G"}, {"x": 180, "y": 320, "name": "H"}, {"x": 90, "y": 450, "name": "I"}, {"x": 600, "y": 350, "name": "J"}],
#                 {"width": 850, "height": 500},
#                 "{}",
#                 "['#EA9972', '#E88265', '#E36C5D', '#DA555C', '#CB4563', '#B73D6A', '#A1376F', '#8B3170', '#752C6E', '#5F2868']"
#             );
# </script>
#
# Rendering chart areachart with fields None and kwargs {'data': [{'date': '2024-01-01', 'catA': 10, 'catB': 20, 'catC': 30}, {'date': '2024-01-02', 'catA': 15, 'catB': 25, 'catC': 35}, {'date': '2024-01-03', 'catA': 20, 'catB': 22, 'catC': 28}, {'date': '2024-01-04', 'catA': 18, 'catB': 30, 'catC': 25}, {'date': '2024-01-05', 'catA': 22, 'catB': 28, 'catC': 32}, {'date': '2024-01-06', 'catA': 19, 'catB': 26, 'catC': 29}, {'date': '2024-01-07', 'catA': 24, 'catB': 30, 'catC': 35}, {'date': '2024-01-08', 'catA': 28, 'catB': 33, 'catC': 40}], 'size': {'width': 500, 'height': 500}, 'colors': 'flare'}
# <p><span class="chart-container" id="areachart_12"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.areachart("#areachart_12",
#                 [{"date": "2024-01-01", "catA": 10, "catB": 20, "catC": 30}, {"date": "2024-01-02", "catA": 15, "catB": 25, "catC": 35}, {"date": "2024-01-03", "catA": 20, "catB": 22, "catC": 28}, {"date": "2024-01-04", "catA": 18, "catB": 30, "catC": 25}, {"date": "2024-01-05", "catA": 22, "catB": 28, "catC": 32}, {"date": "2024-01-06", "catA": 19, "catB": 26, "catC": 29}, {"date": "2024-01-07", "catA": 24, "catB": 30, "catC": 35}, {"date": "2024-01-08", "catA": 28, "catB": 33, "catC": 40}],
#                 {"width": 500, "height": 500},
#                 "{}",
#                 "['#EA9972', '#E88265', '#E36C5D', '#DA555C', '#CB4563', '#B73D6A', '#A1376F', '#8B3170', '#752C6E', '#5F2868']"
#             );
# </script>
# <p><span class="chart-container" id="areachart_12"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.areachart("#areachart_12",
#                 [{"date": "2024-01-01", "catA": 10, "catB": 20, "catC": 30}, {"date": "2024-01-02", "catA": 15, "catB": 25, "catC": 35}, {"date": "2024-01-03", "catA": 20, "catB": 22, "catC": 28}, {"date": "2024-01-04", "catA": 18, "catB": 30, "catC": 25}, {"date": "2024-01-05", "catA": 22, "catB": 28, "catC": 32}, {"date": "2024-01-06", "catA": 19, "catB": 26, "catC": 29}, {"date": "2024-01-07", "catA": 24, "catB": 30, "catC": 35}, {"date": "2024-01-08", "catA": 28, "catB": 33, "catC": 40}],
#                 {"width": 500, "height": 500},
#                 "{}",
#                 "['#EA9972', '#E88265', '#E36C5D', '#DA555C', '#CB4563', '#B73D6A', '#A1376F', '#8B3170', '#752C6E', '#5F2868']"
#             );
# </script>

# %%
import doodl

doodl.bubblechart(
 file={"path": "../data/flare.json", "format": "json"},
size={"width":900,"height":900},
colors='deep',
ease_in = 1,
drag_animations=1
)
# Out:
# Rendering chart bubblechart with fields {'ease_in': 0, 'drag_animations': 0} and kwargs {'file': {'path': '../data/flare.json', 'format': 'json'}, 'size': {'width': 900, 'height': 900}, 'colors': 'deep', 'ease_in': 1, 'drag_animations': 1}
# <p><span class="chart-container" id="bubblechart_13"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.bubblechart("#bubblechart_13",
#                 "[]",
#                 {"width": 900, "height": 900},
#                 {"path": "../data/flare.json", "format": "json"},
#                 "['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD']",
#                 1,
#                 1
#             );
# </script>
# <p><span class="chart-container" id="bubblechart_13"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.bubblechart("#bubblechart_13",
#                 "[]",
#                 {"width": 900, "height": 900},
#                 {"path": "../data/flare.json", "format": "json"},
#                 "['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B3', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD']",
#                 1,
#                 1
#             );
# </script>

# %%
import doodl

doodl.dendrogram(
  file={"path": "../data/dendro.json", "format": "json"},
  size={"width":1000,"height":500},
  colors='pastel'
)
# Out:
# Rendering chart dendrogram with fields {'view_scale_factor': 1} and kwargs {'file': {'path': '../data/dendro.json', 'format': 'json'}, 'size': {'width': 1000, 'height': 500}, 'colors': 'pastel'}
# <p><span class="chart-container" id="dendrogram_14"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.dendrogram("#dendrogram_14",
#                 "[]",
#                 {"width": 1000, "height": 500},
#                 {"path": "../data/dendro.json", "format": "json"},
#                 "['#A1C9F4', '#FFB482', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#DEBB9B', '#FAB0E4', '#CFCFCF', '#FFFEA3', '#B9F2F0']",
#                 "1"
#             );
# </script>
# <p><span class="chart-container" id="dendrogram_14"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.dendrogram("#dendrogram_14",
#                 "[]",
#                 {"width": 1000, "height": 500},
#                 {"path": "../data/dendro.json", "format": "json"},
#                 "['#A1C9F4', '#FFB482', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#DEBB9B', '#FAB0E4', '#CFCFCF', '#FFFEA3', '#B9F2F0']",
#                 "1"
#             );
# </script>

# %%
import doodl

doodl.force(
  file={"path":"../data/miserables.json","format":"json"},
  size={"width":1500,"height":1300},
  colors='pastel'
)
# Out:
# Rendering chart force with fields None and kwargs {'file': {'path': '../data/miserables.json', 'format': 'json'}, 'size': {'width': 1500, 'height': 1300}, 'colors': 'pastel'}
# <p><span class="chart-container" id="force_15"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.force("#force_15",
#                 "[]",
#                 {"width": 1500, "height": 1300},
#                 {"path": "../data/miserables.json", "format": "json"},
#                 "['#A1C9F4', '#FFB482', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#DEBB9B', '#FAB0E4', '#CFCFCF', '#FFFEA3', '#B9F2F0']"
#             );
# </script>
# <p><span class="chart-container" id="force_15"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.force("#force_15",
#                 "[]",
#                 {"width": 1500, "height": 1300},
#                 {"path": "../data/miserables.json", "format": "json"},
#                 "['#A1C9F4', '#FFB482', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#DEBB9B', '#FAB0E4', '#CFCFCF', '#FFFEA3', '#B9F2F0']"
#             );
# </script>

# %%
import doodl

doodl.disjoint(
    file={"path":"../data/graph.json","format":"json"},
    size={"width":1000,"height":1000},
    colors='pastel'
)
# Out:
# Rendering chart disjoint with fields None and kwargs {'file': {'path': '../data/graph.json', 'format': 'json'}, 'size': {'width': 1000, 'height': 1000}, 'colors': 'pastel'}
# <p><span class="chart-container" id="disjoint_16"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.disjoint("#disjoint_16",
#                 "[]",
#                 {"width": 1000, "height": 1000},
#                 {"path": "../data/graph.json", "format": "json"},
#                 "['#A1C9F4', '#FFB482', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#DEBB9B', '#FAB0E4', '#CFCFCF', '#FFFEA3', '#B9F2F0']"
#             );
# </script>
# <p><span class="chart-container" id="disjoint_16"></span></p>
# <script src="https://doodl.ai/assets/doodl/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/menu.css" />
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodlCharts.css" />
# <script type="text/javascript">
#             Doodl.disjoint("#disjoint_16",
#                 "[]",
#                 {"width": 1000, "height": 1000},
#                 {"path": "../data/graph.json", "format": "json"},
#                 "['#A1C9F4', '#FFB482', '#8DE5A1', '#FF9F9B', '#D0BBFF', '#DEBB9B', '#FAB0E4', '#CFCFCF', '#FFFEA3', '#B9F2F0']"
#             );
# </script>
