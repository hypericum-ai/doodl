# %%
# %pip install --quiet --upgrade ../../doodl scipy panflute duckdb tolerantjson numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show doodl
# Out:
# Name: doodl
# Version: 0.8.2
# Summary: A python module for including beautiful charts in Markdown for conversion to HTML
# Home-page:
# Author:
# Author-email: "doodl.ai" <info@doodl.ai>
# License:
# Location: /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages
# Requires: beautifulsoup4, colorcet, ipython, panflute, playwright, pypandoc, requests, seaborn, tolerantjson
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import doodl
doodl.setdevmode()

# %%
doodl.piechart(
    data=[
  { "label": "Apples", "value": 10 },
  { "label": "Bananas", "value": 20 },
  { "label": "Cherries", "value": 15 },
  { "label": "Grapes", "value": 25 }
],
    width=450,
    height=450,
    colors='deep',
    donut = True
)
# Out:
# <p><span class="doodl-chart" id="piechart_4"></span></p>
# <script src="http://localhost:9191/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodl.css" />
# <script type="text/javascript">
#             var doodl = new Doodl.Doodl('');
#             doodl.piechart("#piechart_4",
#                 [{"label": "Apples", "value": 10}, {"label": "Bananas", "value": 20}, {"label": "Cherries", "value": 15}, {"label": "Grapes", "value": 25}],
#                 {"width": 450, "height": 450},
#                 {},
#                 ["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B3", "#937860", "#DA8BC3", "#8C8C8C", "#CCB974", "#64B5CD"],
#                 true,
#                 false,
#                 false
#             );
# </script>

# %%
doodl.linechart(
    file={"path":"../data/xy.csv","format":"csv"},
    size={"width":450,"height":450},
    colors='deep'
)
# Out:
# <p><span class="doodl-chart" id="linechart_5"></span></p>
# <script src="http://localhost:9191/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodl.css" />
# <script type="text/javascript">
#             var doodl = new Doodl.Doodl('');
#             doodl.linechart("#linechart_5",
#                 [{"x": "11", "y": "101"}, {"x": "21", "y": "201"}, {"x": "31", "y": "151"}, {"x": "41", "y": "251"}, {"x": "51", "y": "301"}, {"x": "61", "y": "351"}],
#                 {"width": 450, "height": 450},
#                 {},
#                 ["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B3", "#937860", "#DA8BC3", "#8C8C8C", "#CCB974", "#64B5CD"],
#                 false
#             );
# </script>

# %%
doodl.gantt(
  data=[
    { "task": "Planning", "start": "2024-03-01", "end": "2024-03-05" },
    { "task": "Design", "start": "2024-03-06", "end": "2024-03-12" },
    { "task": "Development", "start": "2024-03-13", "end": "2024-03-25" },
    { "task": "Testing", "start": "2024-03-26", "end": "2024-03-30" },
    { "task": "Deployment", "start": "2024-03-31", "end": "2024-04-02" }
  ],
  size={"width":1000,"height":500},
  colors='deep'
)
# Out:
# <p><span class="doodl-chart" id="gantt_6"></span></p>
# <script src="http://localhost:9191/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodl.css" />
# <script type="text/javascript">
#             var doodl = new Doodl.Doodl('');
#             doodl.gantt("#gantt_6",
#                 [{"task": "Planning", "start": "2024-03-01", "end": "2024-03-05"}, {"task": "Design", "start": "2024-03-06", "end": "2024-03-12"}, {"task": "Development", "start": "2024-03-13", "end": "2024-03-25"}, {"task": "Testing", "start": "2024-03-26", "end": "2024-03-30"}, {"task": "Deployment", "start": "2024-03-31", "end": "2024-04-02"}],
#                 {"width": 1000, "height": 500},
#                 {},
#                 ["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B3", "#937860", "#DA8BC3", "#8C8C8C", "#CCB974", "#64B5CD"]
#             );
# </script>

# %%
doodl.chord(
data=[
  [0, 5, 10, 2],
  [5, 0, 3, 7],
  [10, 3, 0, 6],
  [2, 7, 6, 0]
],
  size={"width":500,"height":500},
  colors='deep'
)
# Out:
# <p><span class="doodl-chart" id="chord_7"></span></p>
# <script src="http://localhost:9191/js/doodlchart.min.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodl.css" />
# <script type="text/javascript">
#             var doodl = new Doodl.Doodl('');
#             doodl.chord("#chord_7",
#                 [[0, 5, 10, 2], [5, 0, 3, 7], [10, 3, 0, 6], [2, 7, 6, 0]],
#                 {"width": 500, "height": 500},
#                 {},
#                 ["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B3", "#937860", "#DA8BC3", "#8C8C8C", "#CCB974", "#64B5CD"],
#                 []
#             );
# </script>
