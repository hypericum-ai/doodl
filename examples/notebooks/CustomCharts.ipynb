# %%
# %pip install --quiet --upgrade ../../doodl scipy panflute duckdb tolerantjson numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import doodl

# %%
defn = {
    "options": {
        "vertical": 0
    },
    "data": {
        "type": "table",
        "columns": [
            "date",
            "close",
            "upper",
            "lower",
            "movingAvg"
        ]
    },
    "tag": "boll2",
    "function": "bollinger",
    "module_name": "BollingerModule",
    "module_source": "https://cdn.jsdelivr.net/gh/hubbl-ai/bollinger-chart@main/dist/bollinger.js"
}

# %%
defn3 = {
    "options": {
        "vertical": 0
    },
    "data": {
        "type": "table",
        "columns": [
            "date",
            "close",
            "upper",
            "lower",
            "movingAvg"
        ]
    },
    "tag": "boll3",
    "function": "bollinger",
    "module_name": "BollingerModule",
    "module_source": "https://cdn.jsdelivr.net/gh/hubbl-ai/bollinger-chart@main/dist/bollinger.js"
}

# %%
ns = doodl.register_chart(source=[defn,defn3])
# Out:
# duplicate chart tag "boll2"

# %%
ns.boll2(
    data=[
      { "date": "2024-03-01", "close": 100, "upper": 105, "lower": 95, "movingAvg": 100 },
      { "date": "2024-03-02", "close": 102, "upper": 107, "lower": 97, "movingAvg": 101 },
      { "date": "2024-03-03", "close": 104, "upper": 109, "lower": 99, "movingAvg": 102 },
      { "date": "2024-03-04", "close": 101, "upper": 106, "lower": 96, "movingAvg": 100.5 },
      { "date": "2024-03-05", "close": 98, "upper": 103, "lower": 93, "movingAvg": 98.5 },
      { "date": "2024-03-06", "close": 96, "upper": 101, "lower": 91, "movingAvg": 96.5 },
      { "date": "2024-03-07", "close": 99, "upper": 104, "lower": 94, "movingAvg": 98 },
      { "date": "2024-03-08", "close": 103, "upper": 108, "lower": 98, "movingAvg": 101 }
    ],
    width=500,
    height=500,
    colors='deep'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ns.boll2(
#       2     data=[
#       3       { "date": "2024-03-01", "close": 100, "upper": 105, "lower": 95, "movingAvg": 100 },
#       4       { "date": "2024-03-02", "close": 102, "upper": 107, "lower": 97, "movingAvg": 101 },
#       5       { "date": "2024-03-03", "close": 104, "upper": 109, "lower": 99, "movingAvg": 102 },
#       6       { "date": "2024-03-04", "close": 101, "upper": 106, "lower": 96, "movingAvg": 100.5 },
#       7       { "date": "2024-03-05", "close": 98, "upper": 103, "lower": 93, "movingAvg": 98.5 },
#       8       { "date": "2024-03-06", "close": 96, "upper": 101, "lower": 91, "movingAvg": 96.5 },
#       9       { "date": "2024-03-07", "close": 99, "upper": 104, "lower": 94, "movingAvg": 98 },
#      10       { "date": "2024-03-08", "close": 103, "upper": 108, "lower": 98, "movingAvg": 101 }
#      11     ],
#      12     width=500,
#      13     height=500,
#      14     colors='deep'
#      15 )
#
# AttributeError: '_namespace' object has no attribute 'boll2'

# %%
ns.boll3(
    data=[
      { "date": "2024-03-01", "close": 100, "upper": 105, "lower": 95, "movingAvg": 100 },
      { "date": "2024-03-02", "close": 102, "upper": 107, "lower": 97, "movingAvg": 101 },
      { "date": "2024-03-03", "close": 104, "upper": 109, "lower": 99, "movingAvg": 102 },
      { "date": "2024-03-04", "close": 101, "upper": 106, "lower": 96, "movingAvg": 100.5 },
      { "date": "2024-03-05", "close": 98, "upper": 103, "lower": 93, "movingAvg": 98.5 },
      { "date": "2024-03-06", "close": 96, "upper": 101, "lower": 91, "movingAvg": 96.5 },
      { "date": "2024-03-07", "close": 99, "upper": 104, "lower": 94, "movingAvg": 98 },
      { "date": "2024-03-08", "close": 103, "upper": 108, "lower": 98, "movingAvg": 101 }
    ],
    width=500,
    height=500,
    colors='deep'
)

# %%
ns

# %%
ns.__dict__
