# %%
# %pip install --quiet --upgrade ../../doodl scipy panflute duckdb tolerantjson numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import doodl

# %%
defn = {
    "options": {
        "vertical": 0
    },
    "data": {
        "type": "table",
        "columns": [
            "date",
            "close",
            "upper",
            "lower",
            "movingAvg"
        ]
    },
    "tag": "boll2",
    "function": "bollinger",
    "module_name": "BollingerModule",
    "module_source": "https://cdn.jsdelivr.net/gh/hubbl-ai/bollinger-chart@main/dist/bollinger.js"
}

# %%
defn3 = {
    "options": {
        "vertical": 0
    },
    "data": {
        "type": "table",
        "columns": [
            "date",
            "close",
            "upper",
            "lower",
            "movingAvg"
        ]
    },
    "tag": "boll3",
    "function": "bollinger",
    "module_name": "BollingerModule",
    "module_source": "https://cdn.jsdelivr.net/gh/hubbl-ai/bollinger-chart@main/dist/bollinger.js"
}

# %%
ns = doodl.register_chart(source=[defn,defn3])
# Out:
# <script src="https://cdn.jsdelivr.net/gh/hubbl-ai/bollinger-chart@main/dist/bollinger.js"></script>

# %%
ns.boll2(
    data=[
      { "date": "2024-03-01", "close": 100, "upper": 105, "lower": 95, "movingAvg": 100 },
      { "date": "2024-03-02", "close": 102, "upper": 107, "lower": 97, "movingAvg": 101 },
      { "date": "2024-03-03", "close": 104, "upper": 109, "lower": 99, "movingAvg": 102 },
      { "date": "2024-03-04", "close": 101, "upper": 106, "lower": 96, "movingAvg": 100.5 },
      { "date": "2024-03-05", "close": 98, "upper": 103, "lower": 93, "movingAvg": 98.5 },
      { "date": "2024-03-06", "close": 96, "upper": 101, "lower": 91, "movingAvg": 96.5 },
      { "date": "2024-03-07", "close": 99, "upper": 104, "lower": 94, "movingAvg": 98 },
      { "date": "2024-03-08", "close": 103, "upper": 108, "lower": 98, "movingAvg": 101 }
    ],
    width=500,
    height=500,
    colors='deep'
)
# Out:
# <p><span class="doodl-chart" id="boll2_0"></span></p>
# <script src="https://cdn.jsdelivr.net/gh/hubbl-ai/bollinger-chart@main/dist/bollinger.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodl.css" />
# <script type="text/javascript">
#             BollingerModule.bollinger("#boll2_0",
#                 [{"date": "2024-03-01", "close": 100, "upper": 105, "lower": 95, "movingAvg": 100}, {"date": "2024-03-02", "close": 102, "upper": 107, "lower": 97, "movingAvg": 101}, {"date": "2024-03-03", "close": 104, "upper": 109, "lower": 99, "movingAvg": 102}, {"date": "2024-03-04", "close": 101, "upper": 106, "lower": 96, "movingAvg": 100.5}, {"date": "2024-03-05", "close": 98, "upper": 103, "lower": 93, "movingAvg": 98.5}, {"date": "2024-03-06", "close": 96, "upper": 101, "lower": 91, "movingAvg": 96.5}, {"date": "2024-03-07", "close": 99, "upper": 104, "lower": 94, "movingAvg": 98}, {"date": "2024-03-08", "close": 103, "upper": 108, "lower": 98, "movingAvg": 101}],
#                 {"width": 500, "height": 500},
#                 {},
#                 ["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B3", "#937860", "#DA8BC3", "#8C8C8C", "#CCB974", "#64B5CD"],
#                 0
#             );
# </script>

# %%
ns.boll3(
    data=[
      { "date": "2024-03-01", "close": 100, "upper": 105, "lower": 95, "movingAvg": 100 },
      { "date": "2024-03-02", "close": 102, "upper": 107, "lower": 97, "movingAvg": 101 },
      { "date": "2024-03-03", "close": 104, "upper": 109, "lower": 99, "movingAvg": 102 },
      { "date": "2024-03-04", "close": 101, "upper": 106, "lower": 96, "movingAvg": 100.5 },
      { "date": "2024-03-05", "close": 98, "upper": 103, "lower": 93, "movingAvg": 98.5 },
      { "date": "2024-03-06", "close": 96, "upper": 101, "lower": 91, "movingAvg": 96.5 },
      { "date": "2024-03-07", "close": 99, "upper": 104, "lower": 94, "movingAvg": 98 },
      { "date": "2024-03-08", "close": 103, "upper": 108, "lower": 98, "movingAvg": 101 }
    ],
    width=500,
    height=500,
    colors='deep'
)
# Out:
# <p><span class="doodl-chart" id="boll3_1"></span></p>
# <script src="https://cdn.jsdelivr.net/gh/hubbl-ai/bollinger-chart@main/dist/bollinger.js"></script>
# <link rel="stylesheet" href="https://doodl.ai/assets/doodl/css/doodl.css" />
# <script type="text/javascript">
#             BollingerModule.bollinger("#boll3_1",
#                 [{"date": "2024-03-01", "close": 100, "upper": 105, "lower": 95, "movingAvg": 100}, {"date": "2024-03-02", "close": 102, "upper": 107, "lower": 97, "movingAvg": 101}, {"date": "2024-03-03", "close": 104, "upper": 109, "lower": 99, "movingAvg": 102}, {"date": "2024-03-04", "close": 101, "upper": 106, "lower": 96, "movingAvg": 100.5}, {"date": "2024-03-05", "close": 98, "upper": 103, "lower": 93, "movingAvg": 98.5}, {"date": "2024-03-06", "close": 96, "upper": 101, "lower": 91, "movingAvg": 96.5}, {"date": "2024-03-07", "close": 99, "upper": 104, "lower": 94, "movingAvg": 98}, {"date": "2024-03-08", "close": 103, "upper": 108, "lower": 98, "movingAvg": 101}],
#                 {"width": 500, "height": 500},
#                 {},
#                 ["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B3", "#937860", "#DA8BC3", "#8C8C8C", "#CCB974", "#64B5CD"],
#                 0
#             );
# </script>

# %%
ns
# Out:
# <doodl.doodl.register_chart.<locals>._namespace at 0x7e1b07305f10>

# %%
ns.__dict__
# Out:
# {'boll2': <function doodl.doodl.chart.<locals>.wrapper(**kwargs)>,
#  'boll3': <function doodl.doodl.chart.<locals>.wrapper(**kwargs)>}
